# %% [markdown]
# ### Print all sub-breeds of hound by making a get request to given URL.
# ### URL : https://dog.ceo/api/breeds/list/all
# ### Print name of sub-breeds in different lines.

# %%
import requests
response = requests.get('https://dog.ceo/api/breeds/list/all')
response.status_code
# Out:
# 200

# %%
python_data = response.json()
for i in python_data['message']['hound']:
    print(i)
# Out:
# afghan
# basset
# blood
# english
# ibizan
# plott
# walker

# %% [markdown]
# ### Print the count of total sub-breeds of poodle from this URL : https://dog.ceo/api/breeds/list/all/.

# %%
count = 0
for i in python_data['message']['poodle']:
    count += 1
print(count)
# Out:
# 3

# %% [markdown]
# ### Print name of all online courses offered by Coding Ninjas. You can fetch the data using their open API :
# ### https://api.codingninjas.com/api/v3/courses .

# %%
import requests
response = requests.get('https://api.codingninjas.com/api/v3/courses')
response.status_code
# Out:
# 200

# %%
python_data = response.json()
data_dictionary = python_data['data']
data_dictionary
# Out:
# {'courses': [{'id': 1,
#    'title': 'C++ & Data Structures',
#    'online_title': 'onlline-c-plus-plus-course',
#    'offline_title': 'classroom-c-plus-plus-course',
#    'name': 'C++ Foundation with Data Structures',
#    'level': 'Foundation Courses',
#    'brief_intro': 'Brief Intro',
#    'preview_image_url': 'https://files.codingninjas.in/0000000000001176.png',
#    'available_online': True,
#    'available_offline': False,
#    'is_career_track': False,
#    'course_group_id': 1,
#    'classroom_icon_url': 'https://files.codingninjas.in/0000000000003771.png'},
#   {'id': 44,
#    'title': 'Premium Machine Learning Course',
#    'online_title': 'premium-machine-learning-course',
#    'offline_title': '',
#    'name': 'Premium Machine Learning Course',
#    'level': 'Foundation Courses',
#    'brief_intro': '',
#    'preview_image_url': '',
#    'available_online': True,
#    'available_offline': False,
#    'is_career_track': False,
#    'course_group_id': 7,
# ...

# %%
courses_list = data_dictionary['courses']
courses_list
# Out:
# [{'id': 1,
#   'title': 'C++ & Data Structures',
#   'online_title': 'onlline-c-plus-plus-course',
#   'offline_title': 'classroom-c-plus-plus-course',
#   'name': 'C++ Foundation with Data Structures',
#   'level': 'Foundation Courses',
#   'brief_intro': 'Brief Intro',
#   'preview_image_url': 'https://files.codingninjas.in/0000000000001176.png',
#   'available_online': True,
#   'available_offline': False,
#   'is_career_track': False,
#   'course_group_id': 1,
#   'classroom_icon_url': 'https://files.codingninjas.in/0000000000003771.png'},
#  {'id': 44,
#   'title': 'Premium Machine Learning Course',
#   'online_title': 'premium-machine-learning-course',
#   'offline_title': '',
#   'name': 'Premium Machine Learning Course',
#   'level': 'Foundation Courses',
#   'brief_intro': '',
#   'preview_image_url': '',
#   'available_online': True,
#   'available_offline': False,
#   'is_career_track': False,
#   'course_group_id': 7,
# ...

# %%
dictionary = {}
answer = []
for i in courses_list:
    if (i['title'] in dictionary):
        continue
    else:
        dictionary[i['title']] = 1
        answer.append(i['title'])
for i in answer:
    print(i)
# Out:
# C++ & Data Structures
# Premium Machine Learning Course
# Premium Android Course
# Machine Learning
# Competitive Programmer
# Premium Web Dev Course
# Front End (React)
# Premium Competitive Course
# Data structures and Algorithms [C++/Java/Python]
# Premium Data Science Course
# Web Dev (Full Stack)
# Java & Data Structures
# Android Developer
# Python & Web Dev (MERN)
# Data Science
# Interview Preparation
# C++ & Web Dev (Node.js)
# Competitive Programming
# Data Scientist
# Python & Data Structures
# Android (Kotlin)
# Aptitude Preparation

# %% [markdown]
# ### Print description of first event from Coding Ninjas Events API
# ### If ther are no events in this API, then print "No Events !"
# ### Data can be fetched from this URL :
# ### Coding Ninjas Events API

# %%
import requests
response = requests.get('https://api.codingninjas.com/api/v3/events?event_category=ALL_EVENTS&event_sub_category=All%20Time%20Favorites&tag_list=&offset=0&_ga=2.229576284.1782627008.1610924880-1081355286.1609886946')
response.status_code
# Out:
# 200

# %%
python_data = response.json()
python_data
# Out:
# {'data': {'events': [{'id': 649,
#     'name': 'Ninja Wave 2.0 at National Institute of Technology, Kurukshetra',
#     'short_desc': '\r\nRun through the wave of codes smoothly and showcase your coding skills to stay ahead amongst your peers.',
#     'cover_picture': 'https://files.codingninjas.in/desktop-6939.png',
#     'registration_start_time': 1609322700,
#     'registration_end_time': 1611757800,
#     'event_start_time': 1611750600,
#     'event_end_time': 1611761400,
#     'venue': 'Online CodeZen',
#     'fees': 0,
#     'currency': 'INR',
#     'registration_status': 'REGISTRATIONS_OPEN',
#     'user_already_registered': None,
#     'start_time': 1609322700,
#     'end_time': 1611757800,
#     'registered_users': {'top_users': [{'name': 'Rishabh Gupta',
#        'image_url': 'https://lh6.googleusercontent.com/-uEvH2DPBcNo/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclLIjyDmCzrHQIobvj_a-FMrYohnw/s96-c/photo.jpg'},
#       {'name': 'hullelo', 'image_url': None},
# ...

# %%
data = python_data['data']
data
# Out:
# {'events': [{'id': 649,
#    'name': 'Ninja Wave 2.0 at National Institute of Technology, Kurukshetra',
#    'short_desc': '\r\nRun through the wave of codes smoothly and showcase your coding skills to stay ahead amongst your peers.',
#    'cover_picture': 'https://files.codingninjas.in/desktop-6939.png',
#    'registration_start_time': 1609322700,
#    'registration_end_time': 1611757800,
#    'event_start_time': 1611750600,
#    'event_end_time': 1611761400,
#    'venue': 'Online CodeZen',
#    'fees': 0,
#    'currency': 'INR',
#    'registration_status': 'REGISTRATIONS_OPEN',
#    'user_already_registered': None,
#    'start_time': 1609322700,
#    'end_time': 1611757800,
#    'registered_users': {'top_users': [{'name': 'Rishabh Gupta',
#       'image_url': 'https://lh6.googleusercontent.com/-uEvH2DPBcNo/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclLIjyDmCzrHQIobvj_a-FMrYohnw/s96-c/photo.jpg'},
#      {'name': 'hullelo', 'image_url': None},
#      {'name': 'Deepak Kumar Mandal',
# ...

# %%
print(data['events'])
# Out:
# [{'id': 649, 'name': 'Ninja Wave 2.0 at National Institute of Technology, Kurukshetra', 'short_desc': '\r\nRun through the wave of codes smoothly and showcase your coding skills to stay ahead amongst your peers.', 'cover_picture': 'https://files.codingninjas.in/desktop-6939.png', 'registration_start_time': 1609322700, 'registration_end_time': 1611757800, 'event_start_time': 1611750600, 'event_end_time': 1611761400, 'venue': 'Online CodeZen', 'fees': 0, 'currency': 'INR', 'registration_status': 'REGISTRATIONS_OPEN', 'user_already_registered': None, 'start_time': 1609322700, 'end_time': 1611757800, 'registered_users': {'top_users': [{'name': 'Rishabh Gupta', 'image_url': 'https://lh6.googleusercontent.com/-uEvH2DPBcNo/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclLIjyDmCzrHQIobvj_a-FMrYohnw/s96-c/photo.jpg'}, {'name': 'hullelo', 'image_url': None}, {'name': 'Deepak Kumar Mandal', 'image_url': 'https://ninjasfiles.s3.amazonaws.com/profile102381d1143c097a8cbb10cb35998d56ef095d.jpeg'}, {'name': 'Restric
# ...

# %%
print(data['events'][0]['short_desc'])
# Out:
# Run through the wave of codes smoothly and showcase your coding skills to stay ahead amongst your peers.

# %% [markdown]
# ### Print the title of course with id=19.
# ### URL : http://api.codingninjas.com/api/v3/courses

# %%
import requests
response = requests.get('https://api.codingninjas.com/api/v3/courses')
python_data = response.json()
python_data
# Out:
# {'data': {'courses': [{'id': 6,
#     'title': 'Machine Learning',
#     'online_title': 'online-machine-learning-course',
#     'offline_title': 'classroom-machine-learning-course',
#     'name': 'Machine Learning & Deep Learning Course',
#     'level': 'Advanced Courses',
#     'brief_intro': 'Machine learning engineers build, implement, and maintain machine learning systems in technology products.',
#     'preview_image_url': 'https://ninjasfiles.s3.amazonaws.com/0000000000001181.png',
#     'available_online': True,
#     'available_offline': False,
#     'is_career_track': False,
#     'course_group_id': 2,
#     'classroom_icon_url': 'https://files.codingninjas.in/0000000000003766.png'},
#    {'id': 41,
#     'title': 'Premium Competitive Course',
#     'online_title': 'premium-competitive-course',
#     'offline_title': '',
#     'name': 'Premium Competitive Programming Course',
#     'level': 'Foundation Courses',
#     'brief_intro': '',
#     'preview_image_url': '',
# ...

# %%
courses = python_data['data']['courses']
courses
# Out:
# [{'id': 6,
#   'title': 'Machine Learning',
#   'online_title': 'online-machine-learning-course',
#   'offline_title': 'classroom-machine-learning-course',
#   'name': 'Machine Learning & Deep Learning Course',
#   'level': 'Advanced Courses',
#   'brief_intro': 'Machine learning engineers build, implement, and maintain machine learning systems in technology products.',
#   'preview_image_url': 'https://ninjasfiles.s3.amazonaws.com/0000000000001181.png',
#   'available_online': True,
#   'available_offline': False,
#   'is_career_track': False,
#   'course_group_id': 2,
#   'classroom_icon_url': 'https://files.codingninjas.in/0000000000003766.png'},
#  {'id': 41,
#   'title': 'Premium Competitive Course',
#   'online_title': 'premium-competitive-course',
#   'offline_title': '',
#   'name': 'Premium Competitive Programming Course',
#   'level': 'Foundation Courses',
#   'brief_intro': '',
#   'preview_image_url': '',
#   'available_online': True,
#   'available_offline': False,
# ...

# %%
courses[-1]['title']
# Out:
# 'Machine Learning'

# %% [markdown]
# ### Count the total number of cities of country AU from this URL : https://api.openaq.org/v1/cities/

# %%
import requests
response = requests.get('https://api.openaq.org/v1/cities/', params = {"country": "AU"})
python_data = response.json()
python_data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 69},
#  'results': [{'country': 'AU',
#    'name': 'Adelaide',
#    'city': 'Adelaide',
#    'count': 265713,
#    'locations': 9},
#   {'country': 'AU',
#    'name': 'Altona North',
#    'city': 'Altona North',
#    'count': 13109,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 1',
#    'city': 'Altona North 1',
#    'count': 81,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Altona North 2',
#    'city': 'Altona North 2',
#    'count': 78,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Bairnsdale',
#    'city': 'Bairnsdale',
#    'count': 981,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Bairnsdale ',
#    'city': 'Bairnsdale ',
#    'count': 50,
#    'locations': 1},
#   {'country': 'AU',
#    'name': 'Bendigo',
#    'city': 'Bendigo',
#    'count': 9427,
# ...

# %%
count = 0
for i in python_data['results']:
    count += 1
print(count)
# Out:
# 69

# %% [markdown]
# ### Print first 5 cities from country “BE”. Fetch the result from given URL.
# ### Order the results by city.
# ### URL - https://api.openaq.org/v1/cities
# ### Documentation - https://docs.openaq.org/

# %%
import requests
response = requests.get('https://api.openaq.org/v1/cities/', params = {"country": "BE"})
python_data = response.json()
python_data
# Out:
# {'meta': {'name': 'openaq-api',
#   'license': 'CC BY 4.0',
#   'website': 'https://docs.openaq.org/',
#   'page': 1,
#   'limit': 100,
#   'found': 14},
#  'results': [{'country': 'BE',
#    'name': 'Antwerpen',
#    'city': 'Antwerpen',
#    'count': 176508,
#    'locations': 24},
#   {'country': 'BE',
#    'name': 'Brabant wallon',
#    'city': 'Brabant wallon',
#    'count': 23396,
#    'locations': 1},
#   {'country': 'BE',
#    'name': 'Brussels',
#    'city': 'Brussels',
#    'count': 121634,
#    'locations': 9},
#   {'country': 'BE',
#    'name': 'Brussels-Capital Region',
#    'city': 'Brussels-Capital Region',
#    'count': 124929,
#    'locations': 11},
#   {'country': 'BE',
#    'name': 'Flanders',
#    'city': 'Flanders',
#    'count': 566501,
#    'locations': 67},
#   {'country': 'BE',
#    'name': 'Hainaut',
#    'city': 'Hainaut',
#    'count': 108529,
#    'locations': 7},
#   {'country': 'BE',
#    'name': 'Liege',
#    'city': 'Liege',
#    'count': 114184,
# ...

# %%
for i in range(0, 5):
    print(python_data['results'][i]['city'])
# Out:
# Antwerpen
# Brabant wallon
# Brussels
# Brussels-Capital Region
# Flanders

# %% [markdown]
# ### Make an API call to -
# ### https://www.metaweather.com/api/location/search/
#
# ### Search for "USA" and print its woeid.
# ### Documentation

# %%
import requests
response = requests.get('https://www.metaweather.com/api/location/search/', params = {"query": "USA"})
python_data = response.json()
print(python_data[0]['woeid'])
# Out:
# 1132447

# %%
import requests
response = requests.get('https://holidayapi.com/v1/holidays', params = {"key": "5766e331-073c-4873-9dca-1d0db18cd499", "year": 2020, "day": 2, "month": 10, "country": "IN"})
python_data = response.json()
python_data
# Out:
# {'status': 200,
#  'warning': 'These results do not include state and province holidays. For more information, please visit https://holidayapi.com/docs',
#  'requests': {'used': 10, 'available': 9990, 'resets': '2021-02-01 00:00:00'},
#  'holidays': [{'name': 'Mahatma Gandhi Jayanti',
#    'date': '2020-10-02',
#    'observed': '2020-10-02',
#    'public': True,
#    'country': 'IN',
#    'uuid': 'b1002352-7376-46e1-a265-f667e40b3727',
#    'weekday': {'date': {'name': 'Friday', 'numeric': '5'},
#     'observed': {'name': 'Friday', 'numeric': '5'}}}]}

# %%
print(python_data['holidays'][0]['name'])
# Out:
# Mahatma Gandhi Jayanti
